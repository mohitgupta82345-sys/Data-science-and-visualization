# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitgupta82345-sys/Data-science-and-visualization/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
sales = pd.Series([2,3,5])

# %%
sales
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %%
sales[2]
# Out:
# np.int64(5)

# %%
sales[0:4]
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
sales.values
# Out:
# array([2, 3, 5])

# %%
sales.dtype
# Out:
# dtype('int64')

# %%
sales.head(2)
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
sales.tail(2)
# Out:
# 1    3
# 2    5
# dtype: int64

# %%
sales.sort_values()
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %%
sales1 = pd.Series([2,1,5,7,3,6,9,8,10])

# %%
sales1
# Out:
# 0     2
# 1     1
# 2     5
# 3     7
# 4     3
# 5     6
# 6     9
# 7     8
# 8    10
# dtype: int64

# %%
sales.count()
sales1.count()
# Out:
# np.int64(9)

# %%
sales.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
sales.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
sales + 2
# Out:
# 0    4
# 1    5
# 2    7
# dtype: int64

# %%
sales**2
# Out:
# 0     4
# 1     9
# 2    25
# dtype: int64

# %%
sales - 1
# Out:
# 0    1
# 1    2
# 2    4
# dtype: int64

# %%
sales_missing = pd.Series([2,None,5])

# %%
sales_missing
# Out:
# 0    2.0
# 1    NaN
# 2    5.0
# dtype: float64

# %%
sales_missing.fillna(1)
# Out:
# 0    2.0
# 1    1.0
# 2    5.0
# dtype: float64

# %%
data = pd.DataFrame({
    'Name' : ['anshul' , 'mehul'] ,
    'id no' : ['03' , '21']
})

# %%
data
# Out:
#      Name id no
# 0  anshul    03
# 1   mehul    21
